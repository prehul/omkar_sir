# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
dataset.head(1)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
#
#    Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       2      0.0              1          1               1        101348.88
#
#    Exited
# 0       1

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

# %%
X=pd.concat([X,geography,gender],axis=1)

## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units= 6, kernel_initializer = 'he_uniform',activation='relu',input_dim = 11))

# %%
# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.5312 - accuracy: 0.7962 - val_loss: 0.5126 - val_accuracy: 0.7955
# Epoch 2/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4881 - accuracy: 0.7977 - val_loss: 0.4836 - val_accuracy: 0.8001
# Epoch 3/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4632 - accuracy: 0.8018 - val_loss: 0.4667 - val_accuracy: 0.8016
# Epoch 4/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4481 - accuracy: 0.8074 - val_loss: 0.4563 - val_accuracy: 0.8035
# Epoch 5/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4389 - accuracy: 0.8089 - val_loss: 0.4500 - val_accuracy: 0.8054
# Epoch 6/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4327 - accuracy: 0.8143 - val_loss: 0.4455 - val_accuracy: 0.8069
# Epoch 7/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4283 - accuracy: 0.8145 - val_loss: 0.4421 - val_accuracy: 0.8084
# Epoch 8/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4251 - accuracy: 0.8149 - val_loss: 0.4392 - val_accuracy: 0.8107
# Epoch 9/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4228 - accuracy: 0.8182 - val_loss: 0.4380 - val_accuracy: 0.8076
# Epoch 10/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4208 - accuracy: 0.8181 - val_loss: 0.4353 - val_accuracy: 0.8122
# Epoch 11/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4193 - accuracy: 0.8205 - val_loss: 0.4343 - val_accuracy: 0.8099
# Epoch 12/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4180 - accuracy: 0.8203 - val_loss: 0.4326 - val_accuracy: 0.8114
# Epoch 13/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4168 - accuracy: 0.8224 - val_loss: 0.4314 - val_accuracy: 0.8126
# Epoch 14/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4157 - accuracy: 0.8233 - val_loss: 0.4311 - val_accuracy: 0.8133
# Epoch 15/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4148 - accuracy: 0.8244 - val_loss: 0.4288 - val_accuracy: 0.8175
# Epoch 16/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4141 - accuracy: 0.8250 - val_loss: 0.4279 - val_accuracy: 0.8164
# Epoch 17/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4134 - accuracy: 0.8276 - val_loss: 0.4270 - val_accuracy: 0.8198
# Epoch 18/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4126 - accuracy: 0.8272 - val_loss: 0.4263 - val_accuracy: 0.8186
# Epoch 19/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4120 - accuracy: 0.8289 - val_loss: 0.4259 - val_accuracy: 0.8186
# Epoch 20/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4112 - accuracy: 0.8278 - val_loss: 0.4253 - val_accuracy: 0.8194
# Epoch 21/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4107 - accuracy: 0.8268 - val_loss: 0.4248 - val_accuracy: 0.8201
# Epoch 22/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4102 - accuracy: 0.8281 - val_loss: 0.4239 - val_accuracy: 0.8205
# Epoch 23/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4097 - accuracy: 0.8287 - val_loss: 0.4238 - val_accuracy: 0.8201
# Epoch 24/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4092 - accuracy: 0.8280 - val_loss: 0.4226 - val_accuracy: 0.8232
# Epoch 25/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4088 - accuracy: 0.8291 - val_loss: 0.4221 - val_accuracy: 0.8239
# Epoch 26/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4081 - accuracy: 0.8287 - val_loss: 0.4213 - val_accuracy: 0.8251
# Epoch 27/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4079 - accuracy: 0.8302 - val_loss: 0.4218 - val_accuracy: 0.8239
# Epoch 28/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4076 - accuracy: 0.8289 - val_loss: 0.4209 - val_accuracy: 0.8243
# Epoch 29/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4072 - accuracy: 0.8308 - val_loss: 0.4208 - val_accuracy: 0.8243
# Epoch 30/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4068 - accuracy: 0.8300 - val_loss: 0.4200 - val_accuracy: 0.8251
# Epoch 31/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4063 - accuracy: 0.8319 - val_loss: 0.4196 - val_accuracy: 0.8251
# Epoch 32/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4059 - accuracy: 0.8302 - val_loss: 0.4190 - val_accuracy: 0.8251
# Epoch 33/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4054 - accuracy: 0.8322 - val_loss: 0.4186 - val_accuracy: 0.8270
# Epoch 34/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4053 - accuracy: 0.8309 - val_loss: 0.4186 - val_accuracy: 0.8239
# Epoch 35/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4044 - accuracy: 0.8315 - val_loss: 0.4177 - val_accuracy: 0.8266
# Epoch 36/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4042 - accuracy: 0.8328 - val_loss: 0.4181 - val_accuracy: 0.8247
# Epoch 37/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4040 - accuracy: 0.8317 - val_loss: 0.4170 - val_accuracy: 0.8258
# Epoch 38/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4036 - accuracy: 0.8326 - val_loss: 0.4165 - val_accuracy: 0.8262
# Epoch 39/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4035 - accuracy: 0.8313 - val_loss: 0.4165 - val_accuracy: 0.8258
# Epoch 40/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4031 - accuracy: 0.8315 - val_loss: 0.4162 - val_accuracy: 0.8254
# Epoch 41/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4028 - accuracy: 0.8313 - val_loss: 0.4158 - val_accuracy: 0.8266
# Epoch 42/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4026 - accuracy: 0.8319 - val_loss: 0.4155 - val_accuracy: 0.8266
# Epoch 43/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4023 - accuracy: 0.8317 - val_loss: 0.4154 - val_accuracy: 0.8281
# Epoch 44/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4020 - accuracy: 0.8319 - val_loss: 0.4153 - val_accuracy: 0.8270
# Epoch 45/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4017 - accuracy: 0.8319 - val_loss: 0.4149 - val_accuracy: 0.8273
# Epoch 46/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4015 - accuracy: 0.8302 - val_loss: 0.4146 - val_accuracy: 0.8277
# Epoch 47/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4012 - accuracy: 0.8328 - val_loss: 0.4139 - val_accuracy: 0.8277
# Epoch 48/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4007 - accuracy: 0.8317 - val_loss: 0.4134 - val_accuracy: 0.8289
# Epoch 49/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4005 - accuracy: 0.8313 - val_loss: 0.4132 - val_accuracy: 0.8296
# Epoch 50/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4001 - accuracy: 0.8315 - val_loss: 0.4129 - val_accuracy: 0.8289
# Epoch 51/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3997 - accuracy: 0.8319 - val_loss: 0.4129 - val_accuracy: 0.8270
# Epoch 52/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3995 - accuracy: 0.8315 - val_loss: 0.4120 - val_accuracy: 0.8296
# Epoch 53/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8339 - val_loss: 0.4115 - val_accuracy: 0.8292
# Epoch 54/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3987 - accuracy: 0.8321 - val_loss: 0.4116 - val_accuracy: 0.8281
# Epoch 55/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3982 - accuracy: 0.8330 - val_loss: 0.4109 - val_accuracy: 0.8273
# Epoch 56/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3977 - accuracy: 0.8322 - val_loss: 0.4101 - val_accuracy: 0.8292
# Epoch 57/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3971 - accuracy: 0.8332 - val_loss: 0.4096 - val_accuracy: 0.8273
# Epoch 58/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3968 - accuracy: 0.8334 - val_loss: 0.4091 - val_accuracy: 0.8277
# Epoch 59/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3962 - accuracy: 0.8330 - val_loss: 0.4090 - val_accuracy: 0.8247
# Epoch 60/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3957 - accuracy: 0.8343 - val_loss: 0.4077 - val_accuracy: 0.8281
# Epoch 61/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3953 - accuracy: 0.8336 - val_loss: 0.4075 - val_accuracy: 0.8258
# Epoch 62/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3945 - accuracy: 0.8339 - val_loss: 0.4062 - val_accuracy: 0.8292
# Epoch 63/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3939 - accuracy: 0.8326 - val_loss: 0.4058 - val_accuracy: 0.8292
# Epoch 64/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3934 - accuracy: 0.8326 - val_loss: 0.4055 - val_accuracy: 0.8270
# Epoch 65/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3927 - accuracy: 0.8337 - val_loss: 0.4048 - val_accuracy: 0.8285
# Epoch 66/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3921 - accuracy: 0.8339 - val_loss: 0.4042 - val_accuracy: 0.8273
# Epoch 67/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3915 - accuracy: 0.8326 - val_loss: 0.4032 - val_accuracy: 0.8273
# Epoch 68/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3906 - accuracy: 0.8345 - val_loss: 0.4020 - val_accuracy: 0.8300
# Epoch 69/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3901 - accuracy: 0.8328 - val_loss: 0.4013 - val_accuracy: 0.8277
# Epoch 70/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3891 - accuracy: 0.8345 - val_loss: 0.4006 - val_accuracy: 0.8292
# Epoch 71/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3884 - accuracy: 0.8332 - val_loss: 0.4002 - val_accuracy: 0.8281
# Epoch 72/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3875 - accuracy: 0.8334 - val_loss: 0.3996 - val_accuracy: 0.8289
# Epoch 73/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3867 - accuracy: 0.8343 - val_loss: 0.3987 - val_accuracy: 0.8311
# Epoch 74/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3859 - accuracy: 0.8339 - val_loss: 0.3974 - val_accuracy: 0.8307
# Epoch 75/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3849 - accuracy: 0.8336 - val_loss: 0.3969 - val_accuracy: 0.8292
# Epoch 76/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3842 - accuracy: 0.8356 - val_loss: 0.3957 - val_accuracy: 0.8307
# Epoch 77/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3832 - accuracy: 0.8343 - val_loss: 0.3949 - val_accuracy: 0.8304
# Epoch 78/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3823 - accuracy: 0.8350 - val_loss: 0.3935 - val_accuracy: 0.8315
# Epoch 79/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3813 - accuracy: 0.8341 - val_loss: 0.3930 - val_accuracy: 0.8315
# Epoch 80/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3802 - accuracy: 0.8362 - val_loss: 0.3916 - val_accuracy: 0.8326
# Epoch 81/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3794 - accuracy: 0.8336 - val_loss: 0.3909 - val_accuracy: 0.8330
# Epoch 82/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3784 - accuracy: 0.8347 - val_loss: 0.3904 - val_accuracy: 0.8326
# Epoch 83/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3775 - accuracy: 0.8352 - val_loss: 0.3892 - val_accuracy: 0.8323
# Epoch 84/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3767 - accuracy: 0.8356 - val_loss: 0.3883 - val_accuracy: 0.8326
# Epoch 85/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3756 - accuracy: 0.8349 - val_loss: 0.3873 - val_accuracy: 0.8342
# Epoch 86/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3748 - accuracy: 0.8352 - val_loss: 0.3869 - val_accuracy: 0.8326
# Epoch 87/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3739 - accuracy: 0.8356 - val_loss: 0.3863 - val_accuracy: 0.8292
# Epoch 88/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3730 - accuracy: 0.8356 - val_loss: 0.3857 - val_accuracy: 0.8307
# Epoch 89/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3724 - accuracy: 0.8352 - val_loss: 0.3848 - val_accuracy: 0.8307
# Epoch 90/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3715 - accuracy: 0.8339 - val_loss: 0.3841 - val_accuracy: 0.8323
# Epoch 91/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3708 - accuracy: 0.8341 - val_loss: 0.3834 - val_accuracy: 0.8319
# Epoch 92/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3702 - accuracy: 0.8349 - val_loss: 0.3830 - val_accuracy: 0.8338
# Epoch 93/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3695 - accuracy: 0.8354 - val_loss: 0.3823 - val_accuracy: 0.8323
# Epoch 94/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3689 - accuracy: 0.8328 - val_loss: 0.3818 - val_accuracy: 0.8326
# Epoch 95/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3684 - accuracy: 0.8352 - val_loss: 0.3815 - val_accuracy: 0.8315
# Epoch 96/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3678 - accuracy: 0.8373 - val_loss: 0.3811 - val_accuracy: 0.8307
# Epoch 97/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3673 - accuracy: 0.8337 - val_loss: 0.3809 - val_accuracy: 0.8323
# Epoch 98/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3668 - accuracy: 0.8349 - val_loss: 0.3803 - val_accuracy: 0.8326
# Epoch 99/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3662 - accuracy: 0.8425 - val_loss: 0.3801 - val_accuracy: 0.8383
# Epoch 100/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3657 - accuracy: 0.8442 - val_loss: 0.3802 - val_accuracy: 0.8379

# %%
# list all data in history

print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step
