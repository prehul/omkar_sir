# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolo-Weights\yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:01<00:00, 6.17MB/s]
# 0: 480x640 1 person, 1 cat, 1 laptop, 445.0ms
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.3
# Class name --> cat
# Speed: 15.4ms preprocess, 445.0ms inference, 2381.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 280.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> mouse
# Speed: 5.0ms preprocess, 280.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 209.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> mouse
# Speed: 3.0ms preprocess, 209.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 201.3ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.42
# Class name --> laptop
# Speed: 2.0ms preprocess, 201.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 mouse, 231.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.29
# Class name --> mouse
# Speed: 4.0ms preprocess, 231.2ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 210.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> mouse
# Speed: 3.5ms preprocess, 210.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 210.3ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.42
# Class name --> mouse
# Confidence ---> 0.41
# Class name --> laptop
# Speed: 3.2ms preprocess, 210.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 mouse, 195.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.45
# Class name --> mouse
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.2ms preprocess, 195.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 223.6ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.48
# Class name --> mouse
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 3.0ms preprocess, 223.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 205.9ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.3
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> mouse
# Speed: 3.0ms preprocess, 205.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 197.5ms
# Confidence ---> 0.63
# Class name --> cat
# Confidence ---> 0.38
# Class name --> person
# Speed: 3.0ms preprocess, 197.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 bottle, 200.4ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.52
# Class name --> cat
# Confidence ---> 0.38
# Class name --> bottle
# Speed: 3.0ms preprocess, 200.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 laptop, 1 vase, 192.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.56
# Class name --> vase
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 2.3ms preprocess, 192.0ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 vase, 191.6ms
# Confidence ---> 0.8
# Class name --> cat
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.66
# Class name --> vase
# Speed: 2.4ms preprocess, 191.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 182.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.37
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> vase
# Speed: 3.0ms preprocess, 182.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 189.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.59
# Class name --> vase
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 2.4ms preprocess, 189.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 179.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.69
# Class name --> vase
# Confidence ---> 0.31
# Class name --> laptop
# Speed: 4.0ms preprocess, 179.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 187.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.6
# Class name --> vase
# Confidence ---> 0.33
# Class name --> laptop
# Speed: 2.3ms preprocess, 187.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 184.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.73
# Class name --> vase
# Confidence ---> 0.47
# Class name --> laptop
# Speed: 2.1ms preprocess, 184.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 187.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.83
# Class name --> vase
# Confidence ---> 0.4
# Class name --> laptop
# Speed: 3.7ms preprocess, 187.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 179.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.8
# Class name --> vase
# Confidence ---> 0.43
# Class name --> laptop
# Speed: 2.0ms preprocess, 179.7ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 200.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.76
# Class name --> vase
# Confidence ---> 0.44
# Class name --> laptop
# Speed: 3.4ms preprocess, 200.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 180.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.74
# Class name --> vase
# Confidence ---> 0.51
# Class name --> laptop
# Speed: 3.0ms preprocess, 180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 179.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.75
# Class name --> vase
# Confidence ---> 0.51
# Class name --> laptop
# Speed: 3.0ms preprocess, 179.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 187.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.77
# Class name --> vase
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 2.0ms preprocess, 187.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 186.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.79
# Class name --> vase
# Confidence ---> 0.49
# Class name --> laptop
# Speed: 3.0ms preprocess, 186.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 vase, 188.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.53
# Class name --> vase
# Confidence ---> 0.42
# Class name --> laptop
# Speed: 3.0ms preprocess, 188.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 186.4ms
# Confidence ---> 0.75
# Class name --> cat
# Confidence ---> 0.43
# Class name --> person
# Speed: 2.2ms preprocess, 186.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 182.7ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 2.4ms preprocess, 182.7ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.0ms
# Confidence ---> 0.6
# Class name --> person
# Speed: 3.0ms preprocess, 195.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 188.0ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 3.0ms preprocess, 188.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.9ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 2.5ms preprocess, 193.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.0ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 3.4ms preprocess, 211.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 laptop, 193.7ms
# Confidence ---> 0.67
# Class name --> cat
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.36
# Class name --> laptop
# Speed: 2.4ms preprocess, 193.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.4ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 3.2ms preprocess, 179.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 187.4ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.33
# Class name --> cat
# Speed: 3.2ms preprocess, 187.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 188.6ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.66
# Class name --> bottle
# Speed: 3.0ms preprocess, 188.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 188.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.42
# Class name --> laptop
# Speed: 2.0ms preprocess, 188.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.0ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.4ms preprocess, 200.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.5ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.5ms preprocess, 179.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.0ms preprocess, 183.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.0ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.0ms preprocess, 194.0ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 168.5ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 3.2ms preprocess, 168.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 197.0ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.45
# Class name --> laptop
# Speed: 3.0ms preprocess, 197.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 188.9ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 4.0ms preprocess, 188.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.0ms
# Confidence ---> 0.51
# Class name --> person
# Speed: 4.2ms preprocess, 181.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 book, 187.1ms
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.29
# Class name --> book
# Speed: 3.3ms preprocess, 187.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 185.0ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.43
# Class name --> book
# Speed: 4.0ms preprocess, 185.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.6ms
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.0ms preprocess, 196.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 book, 184.1ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.29
# Class name --> book
# Speed: 2.0ms preprocess, 184.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 book, 193.8ms
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.34
# Class name --> person
# Speed: 2.0ms preprocess, 193.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 book, 186.1ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.3
# Class name --> person
# Speed: 4.0ms preprocess, 186.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 196.5ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 2.0ms preprocess, 196.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 187.7ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Speed: 2.7ms preprocess, 187.7ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 179.4ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Speed: 2.2ms preprocess, 179.4ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 211.6ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Speed: 3.6ms preprocess, 211.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 194.9ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Speed: 3.0ms preprocess, 194.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 book, 202.5ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Speed: 2.2ms preprocess, 202.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 197.3ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 2.0ms preprocess, 197.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 book, 179.1ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 2.2ms preprocess, 179.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 203.3ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 3.5ms preprocess, 203.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 187.1ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.4
# Class name --> book
# Speed: 3.0ms preprocess, 187.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 183.1ms
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.29
# Class name --> book
# Speed: 2.4ms preprocess, 183.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 179.8ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.29
# Class name --> book
# Speed: 2.0ms preprocess, 179.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 book, 190.7ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> person
# Speed: 4.8ms preprocess, 190.7ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 187.6ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.32
# Class name --> book
# Speed: 2.0ms preprocess, 187.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 187.6ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.47
# Class name --> book
# Speed: 3.0ms preprocess, 187.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 181.9ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Speed: 2.5ms preprocess, 181.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.0ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 2.3ms preprocess, 184.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 196.4ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 3.4ms preprocess, 196.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.6ms
# Confidence ---> 0.49
# Class name --> person
# Speed: 2.4ms preprocess, 199.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 188.5ms
# Confidence ---> 0.48
# Class name --> person
# Speed: 2.0ms preprocess, 188.5ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 189.6ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 2.0ms preprocess, 189.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.7ms
# Confidence ---> 0.37
# Class name --> person
# Speed: 2.4ms preprocess, 191.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 195.2ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Speed: 3.2ms preprocess, 195.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 184.7ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Speed: 2.1ms preprocess, 184.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 190.1ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.0ms preprocess, 190.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 mouse, 2 books, 198.2ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.26
# Class name --> mouse
# Speed: 4.4ms preprocess, 198.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 196.0ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 3.8ms preprocess, 196.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 mouse, 2 books, 184.0ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.34
# Class name --> mouse
# Confidence ---> 0.27
# Class name --> book
# Speed: 4.1ms preprocess, 184.0ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 mouse, 2 books, 192.0ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.52
# Class name --> mouse
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.31
# Class name --> book
# Speed: 3.6ms preprocess, 192.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 188.5ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> mouse
# Confidence ---> 0.3
# Class name --> book
# Speed: 2.3ms preprocess, 188.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 book, 209.0ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.4ms preprocess, 209.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 183.4ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Speed: 3.0ms preprocess, 183.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 books, 192.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.29
# Class name --> book
# Speed: 2.4ms preprocess, 192.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 199.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.39
# Class name --> book
# Speed: 3.0ms preprocess, 199.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 books, 180.7ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.35
# Class name --> book
# Speed: 2.0ms preprocess, 180.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 books, 170.6ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 6.4ms preprocess, 170.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 books, 190.4ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.32
# Class name --> book
# Speed: 3.2ms preprocess, 190.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 199.8ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.45
# Class name --> mouse
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 2.5ms preprocess, 199.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 190.1ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.35
# Class name --> book
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> mouse
# Speed: 2.4ms preprocess, 190.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 208.2ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.4
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 3.4ms preprocess, 208.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 mouse, 2 books, 189.6ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.43
# Class name --> mouse
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.4ms preprocess, 189.6ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 198.6ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 3.3ms preprocess, 198.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bird, 1 mouse, 2 books, 185.0ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.51
# Class name --> mouse
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.26
# Class name --> bird
# Speed: 3.0ms preprocess, 185.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 175.9ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> mouse
# Speed: 2.4ms preprocess, 175.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 mouse, 1 book, 167.2ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.52
# Class name --> mouse
# Confidence ---> 0.42
# Class name --> book
# Speed: 1.8ms preprocess, 167.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 149.7ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.54
# Class name --> mouse
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 2.2ms preprocess, 149.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bird, 1 laptop, 1 mouse, 164.6ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.4
# Class name --> mouse
# Confidence ---> 0.33
# Class name --> bird
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 2.2ms preprocess, 164.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 150.4ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.47
# Class name --> mouse
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 2.6ms preprocess, 150.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bird, 1 mouse, 2 books, 147.4ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.5
# Class name --> bird
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.29
# Class name --> mouse
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.4ms preprocess, 147.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 book, 175.4ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.27
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> book
# Speed: 3.0ms preprocess, 175.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 151.9ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.4
# Class name --> laptop
# Speed: 1.3ms preprocess, 151.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 150.4ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 2.4ms preprocess, 150.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 146.3ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 2.4ms preprocess, 146.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 165.2ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.36
# Class name --> mouse
# Confidence ---> 0.32
# Class name --> laptop
# Speed: 2.2ms preprocess, 165.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 mouse, 1 book, 156.2ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.29
# Class name --> mouse
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.0ms preprocess, 156.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 mouse, 1 book, 170.7ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Confidence ---> 0.29
# Class name --> mouse
# Speed: 3.2ms preprocess, 170.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 170.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.36
# Class name --> laptop
# Speed: 3.4ms preprocess, 170.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 book, 175.0ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.36
# Class name --> book
# Speed: 2.5ms preprocess, 175.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.6ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 2.2ms preprocess, 175.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.8ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 2.2ms preprocess, 169.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 163.5ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.2ms preprocess, 163.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.6ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 3.0ms preprocess, 168.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 158.6ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.3ms preprocess, 158.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 152.3ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 3.5ms preprocess, 152.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.4ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.1ms preprocess, 164.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 laptops, 163.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.44
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 2.4ms preprocess, 163.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.2ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 3.1ms preprocess, 165.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 155.3ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 3.0ms preprocess, 155.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.2ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 2.5ms preprocess, 161.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 154.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 3.3ms preprocess, 154.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.9ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 3.0ms preprocess, 164.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.5ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 2.2ms preprocess, 165.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 156.3ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.4ms preprocess, 156.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.0ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 2.2ms preprocess, 175.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 162.1ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> mouse
# Speed: 2.0ms preprocess, 162.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 173.8ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.4
# Class name --> mouse
# Confidence ---> 0.38
# Class name --> laptop
# Speed: 2.0ms preprocess, 173.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 168.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> mouse
# Speed: 2.4ms preprocess, 168.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 laptops, 164.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 3.0ms preprocess, 164.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 148.1ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.45
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> mouse
# Speed: 4.0ms preprocess, 148.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 164.2ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> mouse
# Speed: 2.0ms preprocess, 164.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 167.2ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> mouse
# Speed: 2.8ms preprocess, 167.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 153.7ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> mouse
# Speed: 2.0ms preprocess, 153.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 162.4ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> mouse
# Speed: 3.1ms preprocess, 162.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 158.2ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> mouse
# Confidence ---> 0.32
# Class name --> book
# Speed: 3.0ms preprocess, 158.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 178.5ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.53
# Class name --> laptop
# Speed: 3.0ms preprocess, 178.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 185.8ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Speed: 2.0ms preprocess, 185.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 173.4ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> mouse
# Confidence ---> 0.28
# Class name --> book
# Speed: 2.2ms preprocess, 173.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 167.7ms
# Confidence ---> 0.64
# Class name --> laptop
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.37
# Class name --> mouse
# Speed: 2.0ms preprocess, 167.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 book, 172.4ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.57
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> book
# Speed: 1.5ms preprocess, 172.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 laptops, 1 mouse, 1 book, 173.6ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.45
# Class name --> mouse
# Confidence ---> 0.44
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> book
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 2.0ms preprocess, 173.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 178.6ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.63
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 2.2ms preprocess, 178.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 174.5ms
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> person
# Speed: 2.4ms preprocess, 174.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 mouse, 174.5ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.48
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> mouse
# Speed: 2.0ms preprocess, 174.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 1 book, 165.2ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.27
# Class name --> book
# Speed: 2.4ms preprocess, 165.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 1 mouse, 2 books, 161.2ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.29
# Class name --> mouse
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.26
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.3ms preprocess, 161.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 161.6ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.59
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> mouse
# Confidence ---> 0.5
# Class name --> book
# Speed: 2.3ms preprocess, 161.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 mouse, 1 book, 172.4ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.42
# Class name --> mouse
# Confidence ---> 0.4
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.34
# Class name --> book
# Speed: 2.0ms preprocess, 172.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 1 mouse, 1 book, 165.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> mouse
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 165.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 1 mouse, 1 book, 158.7ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.3
# Class name --> mouse
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.4ms preprocess, 158.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 167.8ms
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 2.3ms preprocess, 167.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 mouse, 169.0ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.63
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.35
# Class name --> mouse
# Speed: 3.0ms preprocess, 169.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 150.0ms
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.37
# Class name --> mouse
# Confidence ---> 0.28
# Class name --> book
# Speed: 2.4ms preprocess, 150.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 167.2ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.44
# Class name --> laptop
# Speed: 3.2ms preprocess, 167.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 mouse, 154.3ms
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.29
# Class name --> mouse
# Speed: 2.2ms preprocess, 154.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 mouse, 1 book, 199.6ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.58
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.47
# Class name --> mouse
# Confidence ---> 0.41
# Class name --> book
# Speed: 2.0ms preprocess, 199.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 1 mouse, 1 book, 196.0ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.47
# Class name --> book
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.36
# Class name --> mouse
# Confidence ---> 0.34
# Class name --> laptop
# Speed: 2.2ms preprocess, 196.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 1 mouse, 185.6ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> mouse
# Confidence ---> 0.33
# Class name --> laptop
# Speed: 2.4ms preprocess, 185.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 1 book, 171.2ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.26
# Class name --> book
# Speed: 3.0ms preprocess, 171.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 1 mouse, 164.0ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.48
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> mouse
# Speed: 2.7ms preprocess, 164.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 1 mouse, 1 book, 173.6ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.59
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.41
# Class name --> mouse
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.2ms preprocess, 173.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 1 mouse, 1 book, 158.2ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.56
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> book
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 2.9ms preprocess, 158.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 mouse, 150.2ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> mouse
# Confidence ---> 0.36
# Class name --> person
# Speed: 3.5ms preprocess, 150.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 165.0ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> person
# Speed: 2.1ms preprocess, 165.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 1 mouse, 1 book, 149.0ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.57
# Class name --> mouse
# Confidence ---> 0.42
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> book
# Confidence ---> 0.31
# Class name --> person
# Speed: 2.7ms preprocess, 149.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 1 mouse, 1 book, 147.8ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.41
# Class name --> mouse
# Confidence ---> 0.4
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 2.0ms preprocess, 147.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 mouse, 1 book, 172.6ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.61
# Class name --> mouse
# Confidence ---> 0.44
# Class name --> book
# Speed: 3.2ms preprocess, 172.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 152.7ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.45
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> mouse
# Speed: 1.4ms preprocess, 152.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 147.8ms
# Confidence ---> 0.44
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.42
# Class name --> mouse
# Speed: 2.1ms preprocess, 147.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 161.4ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.44
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.29
# Class name --> mouse
# Speed: 2.1ms preprocess, 161.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 162.2ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> mouse
# Confidence ---> 0.28
# Class name --> book
# Speed: 2.0ms preprocess, 162.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 168.0ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> mouse
# Speed: 2.4ms preprocess, 168.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 173.6ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> book
# Confidence ---> 0.33
# Class name --> mouse
# Speed: 2.0ms preprocess, 173.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 169.5ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> mouse
# Speed: 3.2ms preprocess, 169.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.1ms
# Confidence ---> 0.52
# Class name --> person
# Speed: 3.5ms preprocess, 167.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 book, 177.8ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.28
# Class name --> book
# Confidence ---> 0.27
# Class name --> cat
# Speed: 3.2ms preprocess, 177.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 book, 185.1ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.29
# Class name --> book
# Speed: 3.0ms preprocess, 185.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 176.1ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.0ms preprocess, 176.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 165.3ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> mouse
# Speed: 3.0ms preprocess, 165.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 mouse, 159.7ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.37
# Class name --> mouse
# Confidence ---> 0.33
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> person
# Speed: 3.5ms preprocess, 159.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 151.2ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> mouse
# Speed: 2.2ms preprocess, 151.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 mouse, 170.2ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> mouse
# Confidence ---> 0.33
# Class name --> person
# Speed: 2.1ms preprocess, 170.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 155.9ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> laptop
# ...
# Speed: 2.6ms preprocess, 181.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 laptops, 1 mouse, 1 book, 163.4ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> mouse
# Confidence ---> 0.35
# Class name --> laptop
# Speed: 2.1ms preprocess, 163.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 174.1ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.57
# Class name --> mouse
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.34
# Class name --> laptop
# Speed: 3.0ms preprocess, 174.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 laptops, 1 mouse, 1 book, 180.0ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.41
# Class name --> book
# Confidence ---> 0.37
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> mouse
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 3.1ms preprocess, 180.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 152.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.4
# Class name --> mouse
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> book
# Speed: 2.0ms preprocess, 152.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 155.5ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.47
# Class name --> mouse
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> book
# Speed: 2.3ms preprocess, 155.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 laptops, 1 mouse, 1 book, 172.3ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.47
# Class name --> mouse
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.34
# Class name --> laptop
# Speed: 2.1ms preprocess, 172.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 book, 148.4ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.46
# Class name --> book
# Confidence ---> 0.35
# Class name --> laptop
# Speed: 3.3ms preprocess, 148.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 laptops, 1 mouse, 2 books, 159.1ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.42
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> mouse
# Confidence ---> 0.32
# Class name --> book
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 2.0ms preprocess, 159.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 160.9ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> book
# Confidence ---> 0.27
# Class name --> mouse
# Speed: 2.7ms preprocess, 160.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 198.1ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.59
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.29
# Class name --> mouse
# Speed: 1.5ms preprocess, 198.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 book, 195.2ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> book
# Speed: 3.4ms preprocess, 195.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 2 books, 151.4ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> book
# Confidence ---> 0.34
# Class name --> mouse
# Confidence ---> 0.28
# Class name --> book
# Speed: 2.5ms preprocess, 151.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 2 books, 168.9ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.56
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.31
# Class name --> mouse
# Confidence ---> 0.29
# Class name --> book
# Speed: 3.1ms preprocess, 168.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 laptops, 1 mouse, 1 book, 168.7ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> mouse
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.36
# Class name --> laptop
# Speed: 2.4ms preprocess, 168.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 165.7ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> mouse
# Confidence ---> 0.26
# Class name --> book
# Speed: 2.1ms preprocess, 165.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 185.0ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.53
# Class name --> laptop
# Confidence ---> 0.51
# Class name --> mouse
# Confidence ---> 0.46
# Class name --> book
# Speed: 2.0ms preprocess, 185.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 book, 168.2ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.45
# Class name --> book
# Speed: 2.0ms preprocess, 168.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 174.6ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.62
# Class name --> mouse
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.54
# Class name --> laptop
# Speed: 2.3ms preprocess, 174.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 144.6ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.46
# Class name --> mouse
# Confidence ---> 0.38
# Class name --> laptop
# Speed: 2.0ms preprocess, 144.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 152.6ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.45
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> mouse
# Confidence ---> 0.4
# Class name --> book
# Speed: 2.0ms preprocess, 152.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 163.4ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.32
# Class name --> mouse
# Speed: 2.0ms preprocess, 163.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 159.9ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.55
# Class name --> book
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> mouse
# Speed: 2.0ms preprocess, 159.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 168.1ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.58
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.3
# Class name --> mouse
# Speed: 2.2ms preprocess, 168.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 170.1ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.45
# Class name --> mouse
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> book
# Speed: 1.3ms preprocess, 170.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 154.0ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> book
# Confidence ---> 0.29
# Class name --> mouse
# Speed: 3.0ms preprocess, 154.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 182.7ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.52
# Class name --> book
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> mouse
# Speed: 2.7ms preprocess, 182.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 157.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> mouse
# Confidence ---> 0.39
# Class name --> book
# Speed: 2.2ms preprocess, 157.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 laptops, 1 mouse, 1 book, 175.7ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.41
# Class name --> mouse
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 2.0ms preprocess, 175.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 158.7ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.56
# Class name --> book
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> mouse
# Speed: 2.0ms preprocess, 158.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 181.3ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.43
# Class name --> book
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> mouse
# Speed: 2.5ms preprocess, 181.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 184.5ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.5
# Class name --> book
# Confidence ---> 0.46
# Class name --> mouse
# Confidence ---> 0.37
# Class name --> laptop
# Speed: 3.1ms preprocess, 184.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 165.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.45
# Class name --> mouse
# Confidence ---> 0.37
# Class name --> book
# Confidence ---> 0.32
# Class name --> laptop
# Speed: 2.1ms preprocess, 165.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 laptops, 1 mouse, 1 book, 173.3ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.43
# Class name --> mouse
# Confidence ---> 0.33
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 2.0ms preprocess, 173.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 169.3ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.5
# Class name --> mouse
# Confidence ---> 0.48
# Class name --> book
# Confidence ---> 0.44
# Class name --> laptop
# Speed: 2.0ms preprocess, 169.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 sports ball, 1 laptop, 1 mouse, 1 book, 156.1ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.57
# Class name --> mouse
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.37
# Class name --> sports ball
# Speed: 3.2ms preprocess, 156.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 163.5ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> mouse
# Confidence ---> 0.42
# Class name --> book
# Speed: 3.3ms preprocess, 163.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 173.8ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.37
# Class name --> mouse
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> book
# Speed: 2.1ms preprocess, 173.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 155.6ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.38
# Class name --> mouse
# Confidence ---> 0.34
# Class name --> book
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 2.2ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 151.6ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.43
# Class name --> mouse
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> book
# Speed: 2.1ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 155.0ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.58
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> mouse
# Confidence ---> 0.31
# Class name --> book
# Speed: 2.3ms preprocess, 155.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 174.2ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.51
# Class name --> mouse
# Confidence ---> 0.49
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> book
# Speed: 2.4ms preprocess, 174.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 167.6ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.57
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> mouse
# Speed: 3.2ms preprocess, 167.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 164.2ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.57
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> mouse
# Confidence ---> 0.3
# Class name --> book
# Speed: 2.1ms preprocess, 164.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 215.9ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.44
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> mouse
# Speed: 2.1ms preprocess, 215.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 192.4ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.53
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> mouse
# Speed: 2.4ms preprocess, 192.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 189.3ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> book
# Confidence ---> 0.28
# Class name --> mouse
# Speed: 2.7ms preprocess, 189.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 1 book, 177.6ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.47
# Class name --> mouse
# Confidence ---> 0.45
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> book
# Speed: 3.4ms preprocess, 177.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 mouse, 182.8ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> mouse
# Speed: 2.0ms preprocess, 182.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 172.7ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.33
# Class name --> laptop
# Speed: 2.0ms preprocess, 172.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
