# %% [markdown]
# - Step-1: Import the packages
#
# - Step-2: Read the data
#
# - Step-3: EDA ==== good preprocessed data
#
# - Step-4: Divide data into input and output data
#
# - Step-5: Train test split
#
# - Step-6: Develop the model by using train data
#
# - Step-7: Will pass the test input data y_pred
#
# - Step-8: will compare y_pred with test output
#
# - Step-9: Evaluation of model
#
# - Step-10: Will improvise performance of the model
#
# - Step-11: Save the model
#
# - Step-12: Load the model will pass the test cases
#
# - Step-13: Flask API
#
# - Step-14: Application
#
#
# **Linear regression can achive two ways**
#
# 1) Sklearn package
# 2) Statsmodel package   R  SPSS

# %%
###################### ALL together ######################################

# Step-1:
import pandas as pd
df = pd.read_csv("C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Datafiles\\winequality_red.csv")


# Step-2:
X=df.drop('quality',axis=1)
# output
y=df['quality']


# Step-3:
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,
                                                 test_size=0.2,
                                                 random_state=1234)

# Step-4:
print(X_train.shape)   
print(X_test.shape)    
print(y_train.shape)   
print(y_test.shape)
# Out:
# (1279, 11)
# (320, 11)
# (1279,)
# (320,)

# %%
from statsmodels.api import OLS

# %%
results=OLS(y_train,X_train).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared (uncentered):                   0.987
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              8645.
# Date:                Wed, 31 Jan 2024   Prob (F-statistic):                        0.00
# Time:                        19:53:41   Log-Likelihood:                         -1270.3
# No. Observations:                1279   AIC:                                      2563.
# Df Residuals:                    1268   BIC:                                      2619.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# **Hypothesis teting in Linear regresson**
#
# H0: There is no relation between dependent and independent varaible
#
# H1: There is a relation
#
# p<alpha
#
# p<0.05
#
#     - Null hypothesis is rejected
#
#     - Relation is there
#
#     - Corresponding variable can use for model development
#
# From above summary
#
# - Fixed acidity p-value : 0.6
#
# - Citric acid   p-value: 0.5
#
# - Residual sugar  p-value: 0.6
#
# **The above 3 columns need to exclude from the model development**

# %%
AIC:
    - what is the formulae
    
    - what could be better incraese or decreasr
BIC 

ISLP :

# %%
col1   col2   col3

R2(col1,col2)
R2(col1,col3)

col1 as output    col2  as input

VIF= 1/(1-R^2)

# %%
results.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                         Results: Ordinary least squares
# ...
# Model:                  OLS              Adj. R-squared (uncentered): 0.987
# Dependent Variable:     quality          AIC:                         2562.6451
# Date:                   2024-01-31 09:50 BIC:                         2619.3372
# No. Observations:       1279             Log-Likelihood:              -1270.3
# Df Model:               11               F-statistic:                 8645.
# Df Residuals:           1268             Prob (F-statistic):          0.00
# R-squared (uncentered): 0.987            Scale:                       0.43050
# ---------------------------------------------------------------------------------
#                          Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
results.params
# Out:
# fixed acidity          -0.008370
# volatile acidity       -1.103458
# citric acid            -0.107870
# residual sugar          0.006285
# chlorides              -1.728471
# free sulfur dioxide     0.005032
# total sulfur dioxide   -0.003695
# density                 4.735879
# pH                     -0.552635
# sulphates               0.821807
# alcohol                 0.298795
# dtype: float64

# %%
1.30286848e-02,=0.0013   -0.008370
-1.08686529e+00,=-1.08    same
-1.06733841e-01, =0.010   same
1.56488869e-02,-0.0015    littile
-1.69148075e+00,= -1.69   same 
4.82427344e-03, = 0.0048  same
-3.64992541e-03,= 0.0036  same
-1.83253991e+01,=-18      huge
-4.41797201e-01, =0.44    litt 
8.50079329e-01, =0.85     same
2.77289269e-01=0.277      same

# %%
Pytorch  : DL
model is developed by Pytorch framework pre=90

we need to deploy this model on google vertex ai
pytotrch  ==== tensorflow
we deployed the model  pre=60%

# %%
# I shared one note book
# difference between stats model vs Linear model
# just run that today undestand

# generally will use linear model only
