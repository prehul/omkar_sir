# %% [markdown]
# Google colab is python code platform
# offered by google
#
# You need to login with your gmail account
#
# Google offers one GPU free access , One TPU free access
#
# CPU: Central process Unit
# GPU: Graphical process Unit
# TPU: Tensor prpcess unit
#
# RAM: 13GB

# %% [markdown]
# today im learning GeminIAI with python
#
# in your keyboard
# shift+enter at a time

# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
# !pip install google-generativeai
# Install the package

# %%
import os
import google.generativeai as genai
key="AIzaSyBUUejpbU_3eouCT96lkHmkE2mQ6jQb8TU"
genai.configure(api_key=key)
# we are accessing google gemini model
# with our api key

# %%
genai
# Out:
# <module 'google.generativeai' from '/usr/local/lib/python3.10/dist-packages/google/generativeai/__init__.py'>

# %%
for m in genai.list_models():
    print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %% [markdown]
# ## Model

# %% [markdown]
# # Text model : Gemini-pro

# %% [markdown]
# **Prompt Engineering**
#
# - In order to communicate with GenAI machine we need to ask questions in a proper way.
#
# - For the proper question the machine will give proper answer
#
# - Asking this questions is called as **Prompt**
#
# - Asking the questions in a suitable structured is called as **Prompt Engineering**
#
# **Prompt tuning**
#
# - While we are doing prompt will provide some examples is called **Prompt tuning**
#
#
# **Zero short - One short - few short**
#
# - if we provide a prompt with out any examples that is called as **zero short**
#
# - if we provide one example that is called as **one short**
#
# - if we provide multiple examples that is called as **few short**
#
#
# **LLM**
#
# - **Large Language models** is a pretrianed AI model on enemorous data able to generate content and able to think like human

# %%
model=genai.GenerativeModel("gemini-pro")
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
# )

# %%
response=model.generate_content("List of top 5 Indain crickters")
print(response.text)
# Out:
# 1. Sachin Tendulkar
# 2. Virat Kohli
# 3. MS Dhoni
# 4. Sunil Gavaskar
# 5. Kapil Dev

# %% [markdown]
# **Understanding saftey settings**
#
# https://ai.google.dev/gemini-api/docs/safety-settings

# %%
response=model.generate_content("is king jong un cruel guy?")
print(response.parts)
# Out:
# []

# %%
from google.generativeai.types import HarmCategory, HarmBlockThreshold

model=genai.GenerativeModel("gemini-pro")
response = model.generate_content("is king jong un cruel guy?",
    safety_settings={
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
    }
)
response.parts
# Out:
# [text: "Whether or not King Jong Un is considered cruel is a subjective judgement that varies depending on individual perspectives and values. However, there is evidence to suggest that his regime has engaged in human rights abuses, including arbitrary detention, torture, and executions.\n\nFor example, a 2014 United Nations report found that the North Korean government had committed \"systematic, widespread and gross\" human rights violations, including arbitrary detention, torture, and executions. The report also found that the government had created an atmosphere of fear and repression, in which people were afraid to speak out against the regime for fear of retaliation.\n\nIn addition, there have been numerous reports of specific cases of human rights abuses in North Korea. For example, in 2013, a former North Korean prison guard testified before the United Nations Human Rights Council that he had witnessed guards beating and torturing prisoners. He also said that he had seen pris
# ...

# %%
response=model.generate_content("List of top 5 Indain crickters,why they are top in list")
print(response.text)
# Out:
# 1. **Virat Kohli**
#
# * **Reasons for being top:**
#     * Immense batting prowess with an average of over 50 in all three formats
#     * Exceptional leadership skills, leading the Indian cricket team to numerous victories
#     * Consistency and longevity, maintaining a high level of performance for over a decade
#
# 2. **Sachin Tendulkar**
#
# * **Reasons for being top:**
#     * Widely regarded as the greatest batsman of all time, with an unparalleled career spanning 24 years
#     * Holds numerous batting records, including most international runs and centuries
#     * Embodiment of Indian cricket and a role model for countless aspiring players
#
# 3. **Sunil Gavaskar**
#
# * **Reasons for being top:**
#     * Known as the "Little Master" for his technical brilliance and elegance
#     * Pioneered India's dominance in Test cricket during the 1970s
#     * Holds the record for most Test centuries by an Indian batsman
#
# 4. **Kapil Dev**
#
# * **Reasons for being top:**
# ...

# %%
import google.generativeai as genai
api_key="AIzaSyBUUejpbU_3eouCT96lkHmkE2mQ6jQb8TU"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-pro")
response=model.generate_content("Provide me the meaning of name 'omkar' in sanskrit")
print(response.parts)
# Out:
# [text: "\340\244\223\340\244\256\340\245\215 \340\244\225\340\244\276\340\244\260 (O\341\271\203k\304\201ra)"
# ]

# %% [markdown]
# # image model

# %%
from PIL import Image    # Package name : Pillow

# %%
img=Image.open("/content/person.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x424>

# %%
import google.generativeai as genai
api_key="AIzaSyBUUejpbU_3eouCT96lkHmkE2mQ6jQb8TU"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="Generate a Movie title based on above objects "

response=model.generate_content([prompt,img])
#print(response.text)
print(response.parts)
# Out:
# [text: " The Icelandic Horse"
# ]

# %%
import google.generativeai as genai
api_key="AIzaSyBUUejpbU_3eouCT96lkHmkE2mQ6jQb8TU"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="caption the image"

response=model.generate_content([prompt,img])
print(response.text)
# Out:
#  A person walking their horse and dog in a field.

# %%
import google.generativeai as genai
api_key="AIzaSyBUUejpbU_3eouCT96lkHmkE2mQ6jQb8TU"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="write a poem on the above image"

response=model.generate_content([prompt,img])
print(response.text)
# Out:
#  # A Boy and His Dog
#
# A boy and his dog walk through the field,
# The horse looks on, a bit of a yield.
# The dog runs ahead, chasing a ball,
# The boy follows, laughing and carefree.
#
# The horse watches them, a bit wistful,
# Wishing he could join in the fun.
# But he is content to watch,
# And be a part of their world.
#
# The boy and his dog run and play,
# For hours on end, it seems.
# The horse watches, never tiring,
# Of seeing their joy.
#
# Finally, the boy and his dog sit down,
# To rest and catch their breath.
# The horse walks over to them,
# And nuzzles the boy's hand.
#
# The boy smiles and pets the horse,
# And the dog wags his tail.
# The horse is happy to be included,
# And to be a part of their family.

# %%
from PIL import Image
img=Image.open("/content/person.jpg")


import google.generativeai as genai
api_key="AIzaSyBUUejpbU_3eouCT96lkHmkE2mQ6jQb8TU"
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
prompt="write a poem on the above image"

response=model.generate_content([prompt,img])
print(response.text)

# %% [markdown]
# # Create application

# %%
# !pip install streamlit
# !npm install localtunel
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 19.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.6 MB/s eta 0:00:00
# ...
# npm ERR! code E404
# npm ERR! 404 Not Found - GET https://registry.npmjs.org/localtunel - Not found
# npm ERR! 404
# npm ERR! 404  'localtunel@latest' is not in the npm registry.
# npm ERR! 404 You should bug the author to publish it (or use the name yourself!)
# npm ERR! 404
# npm ERR! 404 Note that you can also install from a
# npm ERR! 404 tarball, folder, http url, or git url.
#
# npm ERR! A complete log of this run can be found in:
# npm ERR!     /root/.npm/_logs/2024-05-16T04_58_37_074Z-debug.log

# %%
# %%writefile app.py
import streamlit as st
st.title("hello streamlit")
# Out:
# Writing app.py

# %%
# %%writefile app.py
######## Import the required pacakges ############
import streamlit as st
import google.generativeai as genai
from PIL import Image

####### Provide your api key ###################
api_key="AIzaSyBUUejpbU_3eouCT96lkHmkE2mQ6jQb8TU"
genai.configure(api_key=api_key)

######## Choose the heading ###############
st.header("Image analytics")

########## Upload a file ##################
uploaded_file=st.file_uploader("Upload an image",type=["png","jpg","jpeg"])

if uploaded_file is not None:
    st.image(Image.open(uploaded_file))

############ What you want ask ####################
prompt=st.text_input("Enter the text")

######### Use genai skill ##########################

if st.button("GET RESPONSE"):
    img=Image.open(uploaded_file)
    model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
    response=model.generate_content([prompt,img])
    st.markdown(response.text)
# Out:
# Writing app.py

# %%
# !streamlit run /content/app.py & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.136.216.108
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.136.216.108:8501
#
# npx: installed 22 in 2.959s
# your url is: https://upset-zoos-fix.loca.lt

# %% [markdown]
# ## Embeddings

# %%
import google.generativeai as genai

api_key="AIzaSyBUUejpbU_3eouCT96lkHmkE2mQ6jQb8TU"
genai.configure(api_key=api_key)
result = genai.embed_content(
    model="models/embedding-001",
    content="What is the meaning of life?",
    task_type="retrieval_document",
    title="Embedding of single string")

# 1 input > 1 vector output
print(len(result['embedding']))
print(str(result['embedding'])[:50], '... TRIMMED]')
# Out:
# 768
# [-0.003216741, -0.013358698, -0.017649598, -0.0091 ... TRIMMED]

# %%
result.keys()
# Out:
# dict_keys(['embedding'])
